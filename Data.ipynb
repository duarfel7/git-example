# %% [markdown]
# <h1 align=center><font size = 5>Segmenting and Clustering Neighborhoods in Bogotá D.C.</font></h1>

# %% [markdown]
# Before we get the data and start exploring it, let's download all the dependencies that we will need.

# %%
pip install geopy
# Out:
# Requirement already satisfied: geopy in /Users/duarfel/opt/anaconda3/lib/python3.8/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /Users/duarfel/opt/anaconda3/lib/python3.8/site-packages (from geopy) (1.50)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in /Users/duarfel/opt/anaconda3/lib/python3.8/site-packages (0.11.0)
# Requirement already satisfied: branca>=0.3.0 in /Users/duarfel/opt/anaconda3/lib/python3.8/site-packages (from folium) (0.4.1)
# Requirement already satisfied: requests in /Users/duarfel/opt/anaconda3/lib/python3.8/site-packages (from folium) (2.24.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/duarfel/opt/anaconda3/lib/python3.8/site-packages (from folium) (2.11.2)
# Requirement already satisfied: numpy in /Users/duarfel/opt/anaconda3/lib/python3.8/site-packages (from folium) (1.18.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/duarfel/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/duarfel/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/duarfel/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/duarfel/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2.10)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/duarfel/opt/anaconda3/lib/python3.8/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wget zsh -f
# Out:
# Usage:
#   /Users/duarfel/opt/anaconda3/bin/python -m pip install [options] <requirement specifier> [package-index-options] ...
#   /Users/duarfel/opt/anaconda3/bin/python -m pip install [options] -r <requirements file> [package-index-options] ...
#   /Users/duarfel/opt/anaconda3/bin/python -m pip install [options] [-e] <vcs project url> ...
#   /Users/duarfel/opt/anaconda3/bin/python -m pip install [options] [-e] <local project path> ...
#   /Users/duarfel/opt/anaconda3/bin/python -m pip install [options] <archive url/path> ...
#
# -f option requires 1 argument
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes  #uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# <a id='item1'></a>

# %% [markdown]
# ## 1. Download and Explore Dataset

# %% [markdown]
# Data taken from Bogotá Data website : https://datosabiertos.bogota.gov.co

# %% [markdown]
# For your convenience, I downloaded the files and placed it on the server, so you can simply run a `wget` command and access the data. So let's go ahead and do that.

# %%
# !wget -q -O 'bogota_data.json' https://datosabiertos.bogota.gov.co/dataset/b0c66a77-3230-4d0c-a119-dead7f9b8b8e/resource/9c3829e3-6b4b-4aac-a3e5-297fe0127b67/download/egba.geojson
print('Data downloaded!')
# Out:
# Data downloaded!

# %% [markdown]
# #### Load and explore the data

# %% [markdown]
# Next, let's load the data.

# %%
with open('bogota_data.json') as json_data:
    bogota_data = json.load(json_data)
#bogota_data

# %% [markdown]
# Let's take a quick look at the data.

# %% [markdown]
# Notice how all the relevant data is in the *features* key, which is basically a list of the neighborhoods. So, let's define a new variable that includes this data.

# %%
neighborhoods_data = bogota_data['features']

# %% [markdown]
# Let's take a look at the first item in this list.

# %%
neighborhoods_data[0]
# Out:
# {'type': 'Feature',
#  'properties': {'SUBCATEGOR': 'L',
#   'NOMBRE_EST': 'CHIBCHOMBIA',
#   'DIRECCION': 'CL 27 # 4 - 49 P 1',
#   'LOC': '03',
#   'SECTOR_CAT': 'LA MACARENA',
#   'LATITUD': 4.613799,
#   'LONGITUD': -74.066259},
#  'geometry': {'type': 'Point',
#   'coordinates': [-74.06625899961625, 4.613799000073394]}}

# %% [markdown]
# #### Tranform the data into a *pandas* dataframe

# %% [markdown]
# The next task is essentially transforming this data of nested Python dictionaries into a *pandas* dataframe. So let's start by creating an empty dataframe.

# %%
# define the dataframe columns
column_names = ['Borough','Name','Address','Subcategory', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %% [markdown]
# Take a look at the empty dataframe to confirm that the columns are as intended.

# %%
neighborhoods.head()
# Out:
# Empty DataFrame
# Columns: [Borough, Name, Address, Subcategory, Neighborhood, Latitude, Longitude]
# Index: []

# %% [markdown]
# Then let's loop through the data and fill the dataframe one row at a time.

# %%
for data in neighborhoods_data:
    name = data['properties']['NOMBRE_EST'] 
    LOC = data['properties']['LOC'] 
    address = data['properties']['DIRECCION']
    subcategoy = data['properties']['SUBCATEGOR']
    neighborhood= data['properties']['SECTOR_CAT']
    lat= data['properties']['LATITUD']
    long= data['properties']['LONGITUD']
    
    neighborhoods = neighborhoods.append({'Borough': LOC,
                                          'Name': name,
                                          'Address': address,
                                          'Subcategory':subcategoy,
                                          'Neighborhood': neighborhood,
                                          'Latitude': lat,
                                          'Longitude': long}, ignore_index=True)

# %% [markdown]
# Quickly examine the resulting dataframe.

# %%
neighborhoods.head(100)
# Out:
#    Borough                                           Name  \
# 0       03                                    CHIBCHOMBIA
# 1       03             RESTAURANTE ROMULO Y REMO MACARENA
# 2       03                        BOGOTA BEER COMPANY S A
# 3       03                            PRESTO BTA CALLE 27
# 4       03               LA HAMBURGUESERIA DE LA MACARENA
# 5       03               MC DONALD S CENTRO INTERNACIONAL
# 6       03                             BOCA COCINA LATINA
# 7       03                      GAUDI RESTAURANTE ESPAÑOL
# 8       03                                 REPUBLIK MUSEO
# 9       03                   ARCHIES CENTRO INTERNACIONAL
# 10      03                        RESTAURANTE BTA BAVARIA
# 11      03                 BARRA BTA CENTRO INTERNACIONAL
# 12      03                     DONOSTIA COCINA DE MERCADO
# 13      03                                         TABULA
# 14      08                     RESTAURANTE CALI MIO NO 11
# 15      03  HAMBURGUESAS EL CORRAL PARQUE CENTRAL BAVARIA
# 16      03                                RESTAURANTE WOK
# 17      03                          PRESTO BTA PALMA REAL
# 18      03                                     LA BIFERIA
# 19      03                  RESTAURANTE TRATTORIA BELLINI
# 20      03                 ARACATACA COLOMBIAN STEAKHOUSE
# 21      14                                 SPOLETO-CALIMA
# 22      03                          PRESTO BTA SAN MARTIN
# 23      14                  HAMBURGUESAS EL CORRAL CALIMA
# 24      14                             MC DONALD S CALIMA
# 25      14                           CREPES Y WAFFLES S A
# 26      14                  LEÑOS & CARBON GOURMET CALIMA
# 27      14                DON JEDIONDO SOPITAS Y PARRILLA
# 28      14                           DON JEDIONDO GURME'S
# 29      14                          PPC POLLO PIZZA CARNE
# 30      14                                KOKORIKO CALIMA
# 31      17                         LA ESCUELA RESTAURANTE
# 32      17                   CORRAL GOURMET LA CANDELARIA
# 33      17                          PPC POLLO PIZZA CARNE
# 34      17                                         T-BONE
# 35      17                             SANDWICH CARRERA 7
# 36      17                                     MARFALITOS
# 37      17                  BARRA BTA PALACIO DE JUSTICIA
# 38      17                         BOGOTA BEER COMPANY SA
# 39      17                           CREPES Y WAFFLES S.A
# 40      17                         RESTAURANTE CASA VIEJA
# 41      17                               PRESTO BTA CRA 7
# 42      17                         HAMBURGUESAS DEL RODEO
# 43      03                              RESTAURANTE FELIX
# 44      03                                      REVELLION
# 45      03    HAMBURGUESAS EL CORRAL EDIFICIO CONTINENTAL
# 46      03                     SPOLETO CENTRO CONTINENTAL
# 47      03                      LA ROMANA AVENIDA JIMENEZ
# 48      17                             SANDWICH LOS ANDES
# 49      17                          PPC POLLO PIZZA CARNE
# 50      17                          MCDONALDS AVE JIMENEZ
# 51      17       HAMBURGUESAS EL CORRAL QUINTA DE BOLIVAR
# 52      03                ANDRES EXPRES CASA DE LOS ANDES
# 53      03                        BARRA BTA BANCO POPULAR
# 54      03                              BARRA BTA NUTABES
# 55      03                            LA ROMANA CARRERA 7
# 56      03                          PPC POLLO PIZZA CARNE
# 57      03                         BARRA BTA CRA 7 CLL 22
# 58      03                              PRESTO BTA CLL 23
# 59      03                       SANDWICH TORRE COLPATRIA
# 60      03                      BARRA BTA TORRE COLPATRIA
# 61      03            RESTAURANTE CASA VIEJA DE SAN DIEGO
# 62      03  CERVECERIA IRLANDESA IRISH BREWERY DESDE 2010
# 63      03                      RESTAURANTE LA JUGUETERIA
# 64      14                                     FRISBY G85
# 65      14                            BURGUER KING CALIMA
# 66      14                           PRESTO BTA CALIMA 14
# 67      14               TR3S CU4RTOS PARRILLA EXPRESS CL
# 68      03          BW BUFFALO WINGS CENTRO INTERNACIONAL
# 69      03                             SPOLETO SAN MARTIN
# 70      03              HAMBURGUESAS EL CORRAL SAN MARTIN
# 71      03                                      EL CARNAL
# 72      03                       CENTRICO RESTAURANTE BAR
# 73      03                  CARBON & XILVESTRE SAN MARTIN
# 74      03                   BARRA BTA EXPRESS SAN MARTIN
# 75      08                   HAMBURGUESAS EL CORRAL PLAZA
# 76      08                           CREPES Y WAFFLES S A
# 77      08                DON JEDIONDO SOPITAS Y PARRILLA
# 78      08                                      EL CARNAL
# 79      08                          PPC POLLO PIZZA CARNE
# 80      08              BURGER KING PLAZA DE LAS AMERICAS
# 81      08         PRESTO BTA CALLE PLAZA DE LAS AMERICAS
# 82      08               PRESTO BTA PLAZA DE LAS AMERICAS
# 83      08                          SANDWICH LAS AMERICAS
# 84      08         BARRA BTA C.C. PLAZA DE LAS AMERICAS 1
# 85      08         BARRA BTA C.C. PLAZA DE LAS AMERICAS 2
# 86      08               MCDONALD S PLAZA DE LAS AMERICAS
# 87      08                                   FRISBY NO 43
# 88      08                      KFC PLAZA DE LAS AMERICAS
# 89      08                  SPOLETO PLAZA DE LAS AMERICAS
# 90      03                       BRASA ROJA CC SAN MARTIN
# 91      03                           CREPES Y WAFFLES S.A
# 92      03                 DON JEDIONDO SOPITAS Y PARILLA
# 93      03                        BOGOTA BEER COMPANY S A
# 94      03    HAMBURGUESAS EL CORRAL CENTRO INTERNACIONAL
# 95      08                       SANDWIICH MUNDO AVENTURA
# 96      02                HAMBURGUESAS EL CORRAL PLAZA 39
# 97      02                           CREPES Y WAFFLES S.A
# 98      16                HAMBURGUESAS EL CORRAL AMERICAS
# 99      02               HAMBURGUESAS EL CORRAL JAVERIANA
#
#                                               Address Subcategory  \
# 0                                  CL 27 # 4 - 49 P 1           L
# 1                                    KR 4A # 26D - 90           L
# 2                                      KR 4A # 27 - 3           L
# 3                    KR 7 # 27 - 38 LC 1 ED COLISSEUM           L
# 4                                     KR 4A # 27 - 27           L
# 5                                     KR 10 # 26 - 55           L
# 6   KR 10 # 27 - 51 LC 174 ED Residencias Tequenda...           L
# 7                                     KR 4A # 27 - 52           K
# 8                                 TV 6 # 27 - 50 LC 2           L
# 9                                      KR 7 # 27 - 80           J
# 10                      KR 10 # 27 - 91 INT 117 TRR B           L
# 11                             KR 13 # 27 - 0 LC 9-10           L
# 12                                 CL 29 BIS # 5 - 84           L
# 13                                 CL 29 BIS # 5 - 90           L
# 14                                 KR 70B # 25 - 47 S           L
# 15                              KR 13 # 28 - 1 LC 173           L
# 16                                  KR 6 BIS # 29 - 7           L
# 17                           KR 13 # 28 - 23 LC 1 A 4           L
# 18                                     CL 29 # 6 - 12           L
# 19                                    KR 13 # 29 - 31           L
# 20                             KR 13 # 29 - 31 LC 101           L
# 21                           AC 19 # 28 - 80 LC  R 24           L
# 22                                     KR 7 # 31 - 70           L
# 23                            AC 19 # 28 - 80 LC C 30           L
# 24                             AC 19 # 28 - 80 LC C27           L
# 25                             AC 19 # 28 - 80 LC C32           L
# 26                            AC 19 # 28 - 80 LC C 39           L
# 27                    AK 30 # 19 - 0 CC CALIMA LC R 7           L
# 28                   AK 30 # 19 - 0 CC CALIMA LC C 31           L
# 29                               AC 19 # 28 - 80 C 29           L
# 30                           AK 30 # 19 - 0 CC CALIMA           L
# 31                                      CL 9 # 8 - 77           L
# 32                                     KR 6 # 11 - 20           L
# 33                                     KR 7 # 11 - 96           L
# 34                               KR 4 # 12C - 34 LC 1           L
# 35                          KR 7 # 12 - 37 LC 12 - 37           L
# 36                                 CL 12 # 7 - 32 P 4           L
# 37                                     CL 12 # 8 - 11           L
# 38                                      KR 4 # 15 - 1           L
# 39                                     CL 13 # 4 - 55           L
# 40                                     AC 13 # 3 - 57           J
# 41                                    KR 7 # 12B - 72           L
# 42                                     KR 7 # 13 - 41           L
# 43                                     AC 13 # 4 - 80           L
# 44                                     CL 16 # 4 - 23           K
# 45                     AC 13 # 4 - 16 LC 21 MEZZANINE           L
# 46             CL 13 # 4 - 16 LC 2 P. P ED CONTINENTE           L
# 47                                     AC 13 # 6 - 65           L
# 48                                     CL 18A # 1 - 1           L
# 49                                     AC 13 # 7 - 45           L
# 50                                     AC 13 # 7 - 25           L
# 51                                   CL 19A # 4 - 8 E           L
# 52                                     CL 20 # 1 - 16           L
# 53                                     KR 7 # 16 - 87           L
# 54                              AC 19 # 4 - 71 LC 101           L
# 55                                     KR 7 # 19 - 48           L
# 56                                      KR 7 # 22 - 4           L
# 57                                     KR 7 # 22 - 92           L
# 58                                     KR 7 # 22 - 95           L
# 59                                     KR 7 # 23 - 40           L
# 60                                KR 7 # 24 - 89 LC 5           L
# 61                                    KR 10 # 26 - 60           J
# 62                                    KR 4 # 26D - 15           K
# 63                                     CL 27 # 4A - 3           L
# 64             AK 30 # 19 - 0 CC CALIMA LA 14 LC R 17           L
# 65                    AK 30 # 19 - 0 CC CALIMA LC C26           L
# 66                           AC 22 # 27 - 49 LC 12-19           L
# 67                            AC 19 # 28 - 80 LC R 10           L
# 68         CL 32 # 6B - 43 LC 2 ED SAN MARTIN GOURMET           K
# 69                AK 7 # 32 - 16 LC 406 CC SAN MARTIN           L
# 70                              AK 7 # 32 - 16 LC 409           L
# 71                 AK 7 # 32 - 16 CC SAN MARTIN L 402           L
# 72                                     AK 7 # 32 - 16           K
# 73                              KR 7 # 32 - 12 LC 414           L
# 74                                     AK 7 # 32 - 16           L
# 75                         TV 71D # 26 - 94 S LC 2912           L
# 76                          KR 71D # 6 - 94 S LC 1902           L
# 77  KR 71D # 6 - 94 S CC PLAZA DE LAS AMERICAS LC ...           L
# 78  KR 71D # 6 - 94 S CC PLAZA DE LAS AMERICAS LC ...           L
# 79                         KR 71D # 6 - 94 S LC 25-25           L
# 80                         TV 71D # 26 - 94 S LC 2920           L
# 81                                 KR 71D # 24 - 35 S           L
# 82                          TV 71D # 26 - 94  LC 2921           L
# 83                           TV 71D # 26 - 94 LC 2526           L
# 84                   KR 71D # 6 - 94 S PLAZA DE ROSAS           L
# 85         KR 71D # 6 - 94 S CC PLAZA DE LAS AMERICAS           L
# 86                         TV 71D # 26 - 94 S LC 1500           L
# 87  TV 71D # 26 - 94 S CC PLAZA DE LAS AMERICAS LC...           L
# 88                          KR 71D # 6 - 94 S LC 2925           L
# 89                          KR 71D # 6 - 94 S LC 2909           L
# 90                              AK 7 # 32 - 70 LC 404           L
# 91                              AK 7 # 32 - 84 LC 210           L
# 92                AK 7 # 32 - 70 LC 419 CC SAN MARTIN           L
# 93                                     AK 7 # 32 - 48           L
# 94                                     KR 7 # 32 - 83           L
# 95                                TV 71D # 3 - 05 SUR           L
# 96                              AC 39 # 7 - 40 LC 233           L
# 97                              AC 39 # 7 - 84 LC 137           L
# 98                                    AC 20 # 39 - 22           L
# 99                                     CL 41 # 7 - 29           L
#
#              Neighborhood  Latitude  Longitude
# 0             LA MACARENA  4.613799 -74.066259
# 1             LA MACARENA  4.613799 -74.066259
# 2             LA MACARENA  4.614092 -74.065890
# 3               SAN DIEGO  4.614158 -74.069222
# 4             LA MACARENA  4.614193 -74.066440
# 5               SAN DIEGO  4.614194 -74.070309
# 6               SAN DIEGO  4.614208 -74.070278
# 7             LA MACARENA  4.614401 -74.066068
# 8               SAN DIEGO  4.614652 -74.068623
# 9               SAN DIEGO  4.614853 -74.069126
# 10              SAN DIEGO  4.615318 -74.069642
# 11              SAN DIEGO  4.615481 -74.070010
# 12             SAN MARTIN  4.615880 -74.067316
# 13             SAN MARTIN  4.615909 -74.067380
# 14   PROVIVIENDA ORIENTAL  4.615953 -74.136616
# 15                 SAMPER  4.615995 -74.070131
# 16             SAN MARTIN  4.616127 -74.068341
# 17                 SAMPER  4.616161 -74.069640
# 18             SAN MARTIN  4.616193 -74.068276
# 19                 SAMPER  4.616566 -74.069402
# 20                 SAMPER  4.616566 -74.069402
# 21             PALOQUEMAO  4.618044 -74.086052
# 22             SAN MARTIN  4.618118 -74.068026
# 23             PALOQUEMAO  4.618198 -74.085919
# 24             PALOQUEMAO  4.618198 -74.085919
# 25             PALOQUEMAO  4.618198 -74.085919
# 26             PALOQUEMAO  4.618198 -74.085919
# 27             PALOQUEMAO  4.618198 -74.085919
# 28             PALOQUEMAO  4.618198 -74.085919
# 29             PALOQUEMAO  4.618198 -74.085919
# 30             PALOQUEMAO  4.618198 -74.085919
# 31  CENTRO ADMINISTRATIVO  4.597266 -74.077971
# 32            LA CATEDRAL  4.597684 -74.074021
# 33            LA CATEDRAL  4.598898 -74.074654
# 34            LA CATEDRAL  4.599501 -74.070734
# 35            LA CATEDRAL  4.599518 -74.074840
# 36            LA CATEDRAL  4.599646 -74.075131
# 37            LA CATEDRAL  4.599697 -74.075898
# 38            LA CATEDRAL  4.600337 -74.070495
# 39            LA CATEDRAL  4.600447 -74.070722
# 40            LA CATEDRAL  4.600495 -74.069634
# 41            LA CATEDRAL  4.600532 -74.073767
# 42            LA CATEDRAL  4.600572 -74.074348
# 43               VERACRUZ  4.600889 -74.071500
# 44               VERACRUZ  4.601007 -74.070617
# 45               VERACRUZ  4.601019 -74.070539
# 46               VERACRUZ  4.601019 -74.070539
# 47            LA CATEDRAL  4.601234 -74.073054
# 48              LAS AGUAS  4.601274 -74.066601
# 49            LA CATEDRAL  4.601420 -74.073817
# 50            LA CATEDRAL  4.601421 -74.073810
# 51              LAS AGUAS  4.602115 -74.064257
# 52              LAS AGUAS  4.603347 -74.066359
# 53               VERACRUZ  4.603501 -74.072707
# 54               VERACRUZ  4.603517 -74.069859
# 55             LAS NIEVES  4.605725 -74.071193
# 56             LAS NIEVES  4.608042 -74.070491
# 57             LAS NIEVES  4.608705 -74.070172
# 58             LAS NIEVES  4.609067 -74.070665
# 59             LAS NIEVES  4.609183 -74.069946
# 60             LAS NIEVES  4.610841 -74.070305
# 61              SAN DIEGO  4.612800 -74.069911
# 62            LA MACARENA  4.613468 -74.066030
# 63            LA MACARENA  4.613730 -74.066489
# 64             PALOQUEMAO  4.618198 -74.085919
# 65             PALOQUEMAO  4.618198 -74.085919
# 66             PALOQUEMAO  4.618198 -74.085919
# 67             PALOQUEMAO  4.618198 -74.085919
# 68             SAN MARTIN  4.618468 -74.068000
# 69             SAN MARTIN  4.618768 -74.067710
# 70             SAN MARTIN  4.618813 -74.067743
# 71             SAN MARTIN  4.618813 -74.067743
# 72             SAN MARTIN  4.618813 -74.067743
# 73             SAN MARTIN  4.618813 -74.067743
# 74             SAN MARTIN  4.618813 -74.067743
# 75   HIPOTECHO OCCIDENTAL  4.618838 -74.135188
# 76   HIPOTECHO OCCIDENTAL  4.618838 -74.135188
# 77   HIPOTECHO OCCIDENTAL  4.618838 -74.135188
# 78   HIPOTECHO OCCIDENTAL  4.618838 -74.135188
# 79   HIPOTECHO OCCIDENTAL  4.618838 -74.135188
# 80   HIPOTECHO OCCIDENTAL  4.618838 -74.135188
# 81   HIPOTECHO OCCIDENTAL  4.618838 -74.135188
# 82   HIPOTECHO OCCIDENTAL  4.618838 -74.135188
# 83   HIPOTECHO OCCIDENTAL  4.618838 -74.135188
# 84   HIPOTECHO OCCIDENTAL  4.618838 -74.135188
# 85   HIPOTECHO OCCIDENTAL  4.618838 -74.135188
# 86   HIPOTECHO OCCIDENTAL  4.618916 -74.135288
# 87   HIPOTECHO OCCIDENTAL  4.618916 -74.135288
# 88   HIPOTECHO OCCIDENTAL  4.618916 -74.135288
# 89   HIPOTECHO OCCIDENTAL  4.618916 -74.135288
# 90             SAN MARTIN  4.619163 -74.067594
# 91             SAN MARTIN  4.619163 -74.067594
# 92             SAN MARTIN  4.619163 -74.067594
# 93             SAN MARTIN  4.619163 -74.067594
# 94                 SAMPER  4.619881 -74.068040
# 95              HIPOTECHO  4.625817 -74.136858
# 96                  SUCRE  4.626355 -74.065916
# 97                  SUCRE  4.626357 -74.065906
# 98                ORTEZAL  4.626831 -74.094679
# 99                  SUCRE  4.628584 -74.065446

# %% [markdown]
# And make sure that the dataset has all 5 boroughs and 306 neighborhoods.

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(neighborhoods['Borough'].unique()),
        neighborhoods.shape[0]
    )
)
# Out:
# The dataframe has 15 boroughs and 515 neighborhoods.

# %% [markdown]
# #### Use geopy library to get the latitude and longitude values of Bogotá D.C..

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>ny_explorer</em>, as shown below.

# %%
address = 'Bogota, Colombia'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Bogotá D.C. are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Bogotá D.C. are 4.59808, -74.0760439.

# %% [markdown]
# #### Create a map of Bogota with neighborhoods superimposed on top.

# %%
# create map of New York using latitude and longitude values
map_bogota = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_bogota)  
    
map_bogota
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# As we did with all of Bogotá D.C., let's visualizat bogota the neighborhoods in it.

# %% [markdown]
# Next, we are going to start utilizing the Foursquare API to explore the neighborhoods and segment them.

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'U5HBM0544TWPO4G52TXO5POYFSGGZKHZV0LD1R4CLRND01GN' # your Foursquare ID
CLIENT_SECRET = 'JXOBNNXG3Y3GVUTNR20Q3RY5JGDHEC1LRS3AO1NXRVPZJKIP' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: U5HBM0544TWPO4G52TXO5POYFSGGZKHZV0LD1R4CLRND01GN
# CLIENT_SECRET:JXOBNNXG3Y3GVUTNR20Q3RY5JGDHEC1LRS3AO1NXRVPZJKIP

# %% [markdown]
# #### Let's explore the first neighborhood in our dataframe.

# %% [markdown]
# Get the neighborhood's name.

# %%
neighborhood_fs=neighborhoods.groupby('Neighborhood').mean().reset_index()

neighborhood_fs
# Out:
#                    Neighborhood  Latitude  Longitude
# 0          AEROPUERTO EL DORADO  4.690904 -74.134005
# 1               ANTIGUO COUNTRY  4.671517 -74.057248
# 2                    BELLAVISTA  4.655442 -74.054903
# 3                    BOCHICA II  4.710940 -74.112074
# 4                      CEDRITOS  4.717639 -74.033637
# 5    CEMENTERIO JARDINES APOGEO  4.597093 -74.176075
# 6         CENTRO ADMINISTRATIVO  4.596079 -74.075121
# 7             CHAPINERO CENTRAL  4.640445 -74.065861
# 8               CHAPINERO NORTE  4.652679 -74.061606
# 9                   CHICO NORTE  4.676578 -74.048629
# 10        CHICO NORTE II SECTOR  4.681074 -74.044095
# 11       CHICO NORTE III SECTOR  4.683828 -74.053900
# 12              CIUDAD HAYUELOS  4.663045 -74.131047
# 13  CIUDAD SALITRE NOR-ORIENTAL  4.647601 -74.101629
# 14                       EGIPTO  4.595722 -74.071806
# 15                     EL CHICO  4.673171 -74.051199
# 16                     EL NOGAL  4.666031 -74.052359
# 17                    EL RETIRO  4.667681 -74.053861
# 18                        EMAUS  4.652063 -74.055277
# 19                  ESPARTILLAL  4.666253 -74.055360
# 20                     GALERIAS  4.641968 -74.074671
# 21                      GRANADA  4.651175 -74.056393
# 22                    HIPOTECHO  4.625817 -74.136858
# 23         HIPOTECHO OCCIDENTAL  4.618859 -74.135215
# 24                 JULIO FLOREZ  4.685309 -74.078942
# 25                   LA CABRERA  4.669822 -74.053267
# 26                   LA CALLEJA  4.705538 -74.046193
# 27                  LA CAROLINA  4.708462 -74.038348
# 28                LA CASTELLANA  4.687529 -74.063800
# 29                  LA CATEDRAL  4.599885 -74.073091
# 30           LA ESPERANZA NORTE  4.658984 -74.109891
# 31                  LA MACARENA  4.613926 -74.066205
# 32                   LA SOLEDAD  4.631902 -74.075023
# 33                  LAGO GAITAN  4.664017 -74.058380
# 34                    LAS AGUAS  4.602245 -74.065739
# 35                   LAS CRUCES  4.590128 -74.078886
# 36               LAS MARGARITAS  4.730977 -74.043449
# 37                   LAS NIEVES  4.608594 -74.070462
# 38                   LAS VILLAS  4.712199 -74.071392
# 39                       LISBOA  4.713003 -74.032775
# 40                   LOS ALAMOS  4.683336 -74.120325
# 41                    LOS ANDES  4.685935 -74.074388
# 42                   METROPOLIS  4.680386 -74.082134
# 43                    MIRANDELA  4.762307 -74.046432
# 44                     NIZA SUR  4.704027 -74.071186
# 45                      ORTEZAL  4.626831 -74.094679
# 46                   PALOQUEMAO  4.618186 -74.085929
# 47                  PORCIUNCULA  4.657745 -74.057780
# 48         PROVIVIENDA ORIENTAL  4.615953 -74.136616
# 49               QUINTA CAMACHO  4.655042 -74.058607
# 50                SALAZAR GOMEZ  4.629521 -74.118173
# 51           SALITRE OCCIDENTAL  4.653320 -74.109786
# 52                       SAMPER  4.617034 -74.069323
# 53    SAN ANTONIO NOROCCIDENTAL  4.754545 -74.044705
# 54                    SAN DIEGO  4.614458 -74.069640
# 55           SAN JOSE DEL PRADO  4.723219 -74.062287
# 56                   SAN MARTIN  4.618136 -74.067759
# 57                 SAN PATRICIO  4.697048 -74.046129
# 58         SANTA ANA OCCIDENTAL  4.691934 -74.035453
# 59        SANTA BARBARA CENTRAL  4.702122 -74.041221
# 60     SANTA BARBARA OCCIDENTAL  4.699199 -74.047929
# 61       SANTA BARBARA ORIENTAL  4.696367 -74.032577
# 62                SANTA BIBIANA  4.687713 -74.051573
# 63                 SANTA HELENA  4.732750 -74.066386
# 64                 SANTA MONICA  4.701278 -74.115906
# 65                   SANTA ROSA  4.694849 -74.086496
# 66                        SUCRE  4.627958 -74.065764
# 67                      TORCA I  4.806253 -74.035506
# 68               TUNAL ORIENTAL  4.577897 -74.130324
# 69                      USAQUEN  4.694843 -74.031197
# 70                     VERACRUZ  4.601825 -74.070960
# 71                VILLA ALSACIA  4.645062 -74.129839
# 72                  VILLA ELISA  4.737183 -74.086027
# 73         VILLA MAYOR ORIENTAL  4.592049 -74.123973

# %% [markdown]
# Get the neighborhood's latitude and longitude values.

# %%
neighborhood_latitude = neighborhood_fs.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = neighborhood_fs.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name= neighborhood_fs.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of AEROPUERTO EL DORADO are 4.690904263157895, -74.1340046842105.

# %% [markdown]
# First, let's create the GET request URL. Name your URL **url**.

# %%
# type your answer here

LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION,  
    neighborhood_latitude, 
    neighborhood_longitude,
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=U5HBM0544TWPO4G52TXO5POYFSGGZKHZV0LD1R4CLRND01GN&client_secret=JXOBNNXG3Y3GVUTNR20Q3RY5JGDHEC1LRS3AO1NXRVPZJKIP&v=20180605&ll=4.690904263157895,-74.1340046842105&radius=500&limit=100'

# %% [markdown]
# Send the GET request and examine the resutls

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f1f75a1531fe8660078541a'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Aeropuerto El Dorado',
#   'headerFullLocation': 'Aeropuerto El Dorado, Bogotá',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 22,
#   'suggestedBounds': {'ne': {'lat': 4.695404267657899,
#     'lng': -74.12949798601662},
#    'sw': {'lat': 4.686404258657891, 'lng': -74.13851138240437}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55ef708d498ef7f599495935',
#        'name': 'BBC La Bodega - Terminal Puente Aéreo',
#        'location': {'lat': 4.693784745511199,
#         'lng': -74.13515286278391,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.693784745511199,
#           'lng': -74.13515286278391}],
#         'distance': 345,
#         'cc': 'CO',
#         'country': 'Colombia',
#         'formattedAddress': ['Colombia']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55ef708d498ef7f599495935-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fe73e36e4b04318c4662921',
#        'name': 'Juan Valdez Café',
#        'location': {'address': 'Terminal Puente Aereo Loc 124',
#         'lat': 4.693890504551607,
#         'lng': -74.13519680532997,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.693890504551607,
#           'lng': -74.13519680532997}],
#         'distance': 357,
#         'cc': 'CO',
#         'country': 'Colombia',
#         'formattedAddress': ['Terminal Puente Aereo Loc 124', 'Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fe73e36e4b04318c4662921-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52811c5411d2a397c8ecfc01',
#        'name': 'Top Sushi Wok',
#        'location': {'address': 'Av. El Dorado # 106-39 Local 170',
#         'lat': 4.691265280608282,
#         'lng': -74.13668632507324,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.691265280608282,
#           'lng': -74.13668632507324}],
#         'distance': 300,
#         'cc': 'CO',
#         'city': 'Bogotá',
#         'state': 'Bogotá D.C.',
#         'country': 'Colombia',
#         'formattedAddress': ['Av. El Dorado # 106-39 Local 170',
#          'Bogotá, Bogotá D.C.',
#          'Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52811c5411d2a397c8ecfc01-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd9d73a3f01c9b61d5953a5',
#        'name': 'Juan Valdez Café',
#        'location': {'address': 'Terminal Puente Aereo',
#         'crossStreet': 'Piso 1 - Local 187',
#         'lat': 4.693489398815304,
#         'lng': -74.1347336769104,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.693489398815304,
#           'lng': -74.1347336769104}],
#         'distance': 298,
#         'cc': 'CO',
#         'neighborhood': 'Terminal Puente Aereo',
#         'city': 'Bogotá',
#         'state': 'Bogotá D.C.',
#         'country': 'Colombia',
#         'formattedAddress': ['Terminal Puente Aereo (Piso 1 - Local 187)',
#          'Bogotá, Bogotá D.C.',
#          'Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd9d73a3f01c9b61d5953a5-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '537f7401498e1eadd01ca105',
#        'name': 'Movich Buro 26',
#        'location': {'address': 'Av Calle 26 # 102 - 20',
#         'lat': 4.689655416998871,
#         'lng': -74.13010583213253,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.689655416998871,
#           'lng': -74.13010583213253}],
#         'distance': 454,
#         'cc': 'CO',
#         'neighborhood': 'fonti',
#         'city': 'Aeropuerto El Dorado',
#         'state': 'Bogotá D.C.',
#         'country': 'Colombia',
#         'formattedAddress': ['Av Calle 26 # 102 - 20',
#          'Aeropuerto El Dorado, Bogotá D.C.',
#          'Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-537f7401498e1eadd01ca105-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d9a01c497d06ea8a2e1560b',
#        'name': 'Subway',
#        'location': {'address': 'Centro Administrativo de Carga',
#         'lat': 4.692865444916224,
#         'lng': -74.13643193351402,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.692865444916224,
#           'lng': -74.13643193351402}],
#         'distance': 346,
#         'cc': 'CO',
#         'city': 'Bogotá',
#         'state': 'Bogotá D.C.',
#         'country': 'Colombia',
#         'formattedAddress': ['Centro Administrativo de Carga',
#          'Bogotá, Bogotá D.C.',
#          'Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d9a01c497d06ea8a2e1560b-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d8d509ecb9b224b189a6a41',
#        'name': 'Subway',
#        'location': {'address': 'Aeropuerto Internacional El Dorado (BOG)',
#         'crossStreet': 'Local 113',
#         'lat': 4.68951095513002,
#         'lng': -74.1327386065324,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.68951095513002,
#           'lng': -74.1327386065324}],
#         'distance': 209,
#         'cc': 'CO',
#         'city': 'Bogotá',
#         'state': 'Bogotá D.C.',
#         'country': 'Colombia',
#         'formattedAddress': ['Aeropuerto Internacional El Dorado (BOG) (Local 113)',
#          'Bogotá, Bogotá D.C.',
#          'Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d8d509ecb9b224b189a6a41-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca48045554b236a767a2f48',
#        'name': "Pan Pa' Ya!",
#        'location': {'address': 'Puente Aereo',
#         'lat': 4.692940534322134,
#         'lng': -74.13378165908031,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.692940534322134,
#           'lng': -74.13378165908031}],
#         'distance': 228,
#         'cc': 'CO',
#         'neighborhood': 'Aeropuerto El Dorado',
#         'city': 'Bogotá',
#         'state': 'Bogotá D.C.',
#         'country': 'Colombia',
#         'formattedAddress': ['Puente Aereo',
#          'Bogotá, Bogotá D.C.',
#          'Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca48045554b236a767a2f48-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c9fb6eb46978cfa1e8bad7f',
#        'name': "Dunkin'",
#        'location': {'address': 'Puente Aéreo',
#         'lat': 4.693978749229793,
#         'lng': -74.13507638075487,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.693978749229793,
#           'lng': -74.13507638075487}],
#         'distance': 362,
#         'cc': 'CO',
#         'city': 'Bogotá',
#         'state': 'Bogotá D.C.',
#         'country': 'Colombia',
#         'formattedAddress': ['Puente Aéreo',
#          'Bogotá, Bogotá D.C.',
#          'Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d148941735',
#          'name': 'Donut Shop',
#          'pluralName': 'Donut Shops',
#          'shortName': 'Donuts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c9fb6eb46978cfa1e8bad7f-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb749343ac937044c86da0a',
#        'name': 'OMA',
#        'location': {'address': 'Puente Aéreo',
#         'lat': 4.693892823241544,
#         'lng': -74.13512419006638,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.693892823241544,
#           'lng': -74.13512419006638}],
#         'distance': 355,
#         'cc': 'CO',
#         'city': 'Bogotá',
#         'state': 'Bogotá D.C.',
#         'country': 'Colombia',
#         'formattedAddress': ['Puente Aéreo',
#          'Bogotá, Bogotá D.C.',
#          'Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb749343ac937044c86da0a-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb2826a35f0c9b60262bb83',
#        'name': 'Terminal Puente Aéreo',
#        'location': {'address': 'Aeropuerto Internacional El Dorado',
#         'lat': 4.69337378226823,
#         'lng': -74.13435816764832,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.69337378226823,
#           'lng': -74.13435816764832}],
#         'distance': 277,
#         'postalCode': '110911',
#         'cc': 'CO',
#         'city': 'Bogotá',
#         'state': 'Bogotá D.C.',
#         'country': 'Colombia',
#         'formattedAddress': ['Aeropuerto Internacional El Dorado',
#          'Bogotá, Bogotá D.C.',
#          'Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d1eb931735',
#          'name': 'Airport Terminal',
#          'pluralName': 'Airport Terminals',
#          'shortName': 'Terminal',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb2826a35f0c9b60262bb83-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd98a621891236a79ff3b0b',
#        'name': 'Sansai',
#        'location': {'address': 'Puente Aéreo',
#         'crossStreet': 'E1-P2',
#         'lat': 4.6931327321233685,
#         'lng': -74.13382721242328,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.6931327321233685,
#           'lng': -74.13382721242328}],
#         'distance': 248,
#         'cc': 'CO',
#         'city': 'Bogotá',
#         'state': 'Bogotá D.C.',
#         'country': 'Colombia',
#         'formattedAddress': ['Puente Aéreo (E1-P2)',
#          'Bogotá, Bogotá D.C.',
#          'Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd98a621891236a79ff3b0b-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf7bc9866585481ec58d098',
#        'name': 'Terminal de Carga Aéreo',
#        'location': {'lat': 4.693392469995909,
#         'lng': -74.13687321637356,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.693392469995909,
#           'lng': -74.13687321637356}],
#         'distance': 421,
#         'cc': 'CO',
#         'city': 'Bogotá',
#         'state': 'Bogotá D.C.',
#         'country': 'Colombia',
#         'formattedAddress': ['Bogotá, Bogotá D.C.', 'Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d1eb931735',
#          'name': 'Airport Terminal',
#          'pluralName': 'Airport Terminals',
#          'shortName': 'Terminal',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf7bc9866585481ec58d098-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d7bb5cc73ca5481bd94507c',
#        'name': 'Zirope -Puente Aéreo',
#        'location': {'address': 'Puente aéreo - 2o Piso',
#         'crossStreet': 'Plaza de comidas',
#         'lat': 4.693963828516891,
#         'lng': -74.13497580881679,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.693963828516891,
#           'lng': -74.13497580881679}],
#         'distance': 357,
#         'cc': 'CO',
#         'city': 'Bogotá',
#         'state': 'Bogotá D.C.',
#         'country': 'Colombia',
#         'formattedAddress': ['Puente aéreo - 2o Piso (Plaza de comidas)',
#          'Bogotá, Bogotá D.C.',
#          'Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d7bb5cc73ca5481bd94507c-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58a3841c761b1a2a6df2449f',
#        'name': 'JUGOS COSECHAS EDIFICIO BURO 26',
#        'location': {'lat': 4.69068,
#         'lng': -74.13123,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.69068,
#           'lng': -74.13123}],
#         'distance': 308,
#         'postalCode': '110911',
#         'cc': 'CO',
#         'city': 'Bogotá',
#         'state': 'Bogotá D.C.',
#         'country': 'Colombia',
#         'formattedAddress': ['Bogotá, Bogotá D.C.', 'Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'shortName': 'Juice Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58a3841c761b1a2a6df2449f-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d960d6f0caaa143c2aa6db3',
#        'name': 'Typykos Aeropuerto El Dorado',
#        'location': {'address': 'Calle 26 # 93-30',
#         'lat': 4.692638340735129,
#         'lng': -74.13628256342724,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.692638340735129,
#           'lng': -74.13628256342724}],
#         'distance': 318,
#         'postalCode': '111071',
#         'cc': 'CO',
#         'city': 'Bogotá D. C.',
#         'state': 'Cundinamarca',
#         'country': 'Colombia',
#         'formattedAddress': ['Calle 26 # 93-30',
#          'Bogotá D. C., Cundinamarca',
#          'Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d960d6f0caaa143c2aa6db3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5322163511d2041b58e9f882',
#        'name': 'Manduka',
#        'location': {'lat': 4.688685123409365,
#         'lng': -74.13093792954626,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.688685123409365,
#           'lng': -74.13093792954626}],
#         'distance': 420,
#         'cc': 'CO',
#         'country': 'Colombia',
#         'formattedAddress': ['Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d1cd941735',
#          'name': 'South American Restaurant',
#          'pluralName': 'South American Restaurants',
#          'shortName': 'South American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5322163511d2041b58e9f882-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50c0eb4fe4b0b9353b327d82',
#        'name': 'Gym Habitel - Bogota',
#        'location': {'lat': 4.688574392920683,
#         'lng': -74.13091499087405,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.688574392920683,
#           'lng': -74.13091499087405}],
#         'distance': 429,
#         'cc': 'CO',
#         'country': 'Colombia',
#         'formattedAddress': ['Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50c0eb4fe4b0b9353b327d82-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5502d4ff498e0bf8d8c2eeef',
#        'name': 'Best Cake',
#        'location': {'lat': 4.689430024541585,
#         'lng': -74.1302784415975,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.689430024541585,
#           'lng': -74.1302784415975}],
#         'distance': 444,
#         'cc': 'CO',
#         'country': 'Colombia',
#         'formattedAddress': ['Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5502d4ff498e0bf8d8c2eeef-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e82064d7ee61ffc04f27adc',
#        'name': 'Frisby',
#        'location': {'address': 'Terminal de Carga Internacional',
#         'lat': 4.692895569923751,
#         'lng': -74.13633417395334,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.692895569923751,
#           'lng': -74.13633417395334}],
#         'distance': 340,
#         'cc': 'CO',
#         'city': 'Bogotá',
#         'state': 'Bogotá D.C.',
#         'country': 'Colombia',
#         'formattedAddress': ['Terminal de Carga Internacional',
#          'Bogotá, Bogotá D.C.',
#          'Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e82064d7ee61ffc04f27adc-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f799327e4b05c37fd62262b',
#        'name': 'Hangar Aerotecnico',
#        'location': {'lat': 4.695066002454924,
#         'lng': -74.13467689549279,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.695066002454924,
#           'lng': -74.13467689549279}],
#         'distance': 469,
#         'cc': 'CO',
#         'country': 'Colombia',
#         'formattedAddress': ['Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d1eb931735',
#          'name': 'Airport Terminal',
#          'pluralName': 'Airport Terminals',
#          'shortName': 'Terminal',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f799327e4b05c37fd62262b-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56197e3b498e8f2d1f835dd0',
#        'name': 'Avitta Spa',
#        'location': {'address': 'Av. Eldorado No. 102 - 20',
#         'lat': 4.689843,
#         'lng': -74.129751,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 4.689843,
#           'lng': -74.129751}],
#         'distance': 486,
#         'cc': 'CO',
#         'city': 'Bogotá',
#         'state': 'Bogotá D.C.',
#         'country': 'Colombia',
#         'formattedAddress': ['Av. Eldorado No. 102 - 20',
#          'Bogotá, Bogotá D.C.',
#          'Colombia']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56197e3b498e8f2d1f835dd0-21'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Now we are ready to clean the json and structure it into a *pandas* dataframe.

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# <ipython-input-22-561c05f0fdd1>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   nearby_venues = json_normalize(venues) # flatten JSON
#                                     name        categories       lat  \
# 0  BBC La Bodega - Terminal Puente Aéreo           Brewery  4.693785
# 1                       Juan Valdez Café              Café  4.693891
# 2                          Top Sushi Wok  Sushi Restaurant  4.691265
# 3                       Juan Valdez Café              Café  4.693489
# 4                         Movich Buro 26             Hotel  4.689655
#
#          lng
# 0 -74.135153
# 1 -74.135197
# 2 -74.136686
# 3 -74.134734
# 4 -74.130106

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 22 venues were returned by Foursquare.

# %% [markdown]
# <a id='item2'></a>
